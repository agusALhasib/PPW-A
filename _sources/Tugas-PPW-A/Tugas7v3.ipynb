# %% [markdown]
# # Clustering dengan Fuzzy C-Means

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv("/content/drive/My Drive/PPW-A/report/Tugas-PPW-A/hasil_preprocesing.csv")
df.head()
# Out:
#                                                judul  \
# 0  Jakarta Cycling Challenge 2024: Ajang Cari Bib...
# 1  Soal Cabor yang Dualisme, Wamenpora Taufik: Ka...
# 2  Wamenpora Taufik Bakal Prioritaskan Cabor Olim...
# 3  Budisatrio Ingin Lebih Banyak Perempuan dalam ...
# 4  Liga Taekwondo DKI Jakarta: Demi Pembinaan Atl...
#
#                          tanggal  \
# 0    Rabu, 30 Okt 2024 18:55 WIB
# 1    Rabu, 30 Okt 2024 14:30 WIB
# 2    Rabu, 30 Okt 2024 13:30 WIB
# 3    Rabu, 30 Okt 2024 12:50 WIB
# 4  Selasa, 29 Okt 2024 23:15 WIB
#
#                                                  isi  kategori  \
# 0  Jakarta - Pagelaran Jakarta Cycling Challenge ...  Olahraga
# 1  Jakarta - Wakil Menpora Taufik Hidayat segera ...  Olahraga
# 2  Jakarta - Wakil Menpora Taufik Hidayat mengata...  Olahraga
# 3  Jakarta - Budisatrio Djiwandono terpilih menja...  Olahraga
# 4  Jakarta - Liga Taekwondo DKI Jakarta baru saja...  Olahraga
#
#                                            cleansing  \
# 0  Jakarta  Pagelaran Jakarta Cycling Challenge  ...
# 1  Jakarta  Wakil Menpora Taufik Hidayat segera m...
# 2  Jakarta  Wakil Menpora Taufik Hidayat mengatak...
# 3  Jakarta  Budisatrio Djiwandono terpilih menjad...
# 4  Jakarta  Liga Taekwondo DKI Jakarta baru saja ...
#
#                                         case_folding  \
# 0  jakarta  pagelaran jakarta cycling challenge  ...
# 1  jakarta  wakil menpora taufik hidayat segera m...
# 2  jakarta  wakil menpora taufik hidayat mengatak...
# 3  jakarta  budisatrio djiwandono terpilih menjad...
# 4  jakarta  liga taekwondo dki jakarta baru saja ...
#
#                                             tokenize  \
# 0  ['jakarta', 'pagelaran', 'jakarta', 'cycling',...
# 1  ['jakarta', 'wakil', 'menpora', 'taufik', 'hid...
# 2  ['jakarta', 'wakil', 'menpora', 'taufik', 'hid...
# 3  ['jakarta', 'budisatrio', 'djiwandono', 'terpi...
# 4  ['jakarta', 'liga', 'taekwondo', 'dki', 'jakar...
#
#                           Filtering/stopword removal
# 0  jakarta pagelaran jakarta cycling challenge aj...
# 1  jakarta wakil menpora taufik hidayat memanggil...
# 2  jakarta wakil menpora taufik hidayat memperhat...
# 3  jakarta budisatrio djiwandono terpilih ketua p...
# 4  jakarta liga taekwondo dki jakarta menuntaskan...
