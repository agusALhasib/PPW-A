# %% [markdown]
# # Clustering dengan Fuzzy C-Means

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv("/content/drive/My Drive/PPW-A/report/Tugas-PPW-A/hasil_preprocesing.csv")
df.head()
# Out:
#                                                judul  \
# 0  Kualifikasi F1 GP Las Vegas: Russell Pole, Ver...
# 1  Triple Kill Jonatan Chrisite di China Masters:...
# 2  China Masters 2024: Singkirkan Shi Yu Qi, Jona...
# 3  Tangkal Judol, Menpora Mau Perbanyak Gelar Kej...
# 4              Vinales Bidik Rekor Ini Bersama Tech3
#
#                         tanggal  \
# 0  Sabtu, 23 Nov 2024 15:05 WIB
# 1  Sabtu, 23 Nov 2024 15:04 WIB
# 2  Sabtu, 23 Nov 2024 14:04 WIB
# 3  Sabtu, 23 Nov 2024 11:50 WIB
# 4  Sabtu, 23 Nov 2024 10:50 WIB
#
#                                                  isi  kategori  \
# 0  Las Vegas - Pebalap Mercedes George Russell me...  Olahraga
# 1  Shenzhen - Jonatan Christie sukses menembus pa...  Olahraga
# 2  Jakarta - China Masters 2024 jalani babak semi...  Olahraga
# 3  Jakarta - Kejuaraan Antarkampung (Tarkam) biki...  Olahraga
# 4  Montmelo - Pebalap Tech3 KTM Maverick Vinales ...  Olahraga
#
#                                            cleansing  \
# 0  Las Vegas  Pebalap Mercedes George Russell mer...
# 1  Shenzhen  Jonatan Christie sukses menembus par...
# 2  Jakarta  China Masters  jalani babak semifinal...
# 3  Jakarta  Kejuaraan Antarkampung Tarkam bikinan...
# 4  Montmelo  Pebalap Tech KTM Maverick Vinales op...
#
#                                         case_folding  \
# 0  las vegas  pebalap mercedes george russell mer...
# 1  shenzhen  jonatan christie sukses menembus par...
# 2  jakarta  china masters  jalani babak semifinal...
# 3  jakarta  kejuaraan antarkampung tarkam bikinan...
# 4  montmelo  pebalap tech ktm maverick vinales op...
#
#                                             tokenize  \
# 0  ['las', 'vegas', 'pebalap', 'mercedes', 'georg...
# 1  ['shenzhen', 'jonatan', 'christie', 'sukses', ...
# 2  ['jakarta', 'china', 'masters', 'jalani', 'bab...
# 3  ['jakarta', 'kejuaraan', 'antarkampung', 'tark...
# 4  ['montmelo', 'pebalap', 'tech', 'ktm', 'maveri...
#
#                           Filtering/stopword removal
# 0  las vegas pebalap mercedes george russell mera...
# 1  shenzhen jonatan christie sukses menembus part...
# 2  jakarta china masters jalani babak semifinal j...
# 3  jakarta kejuaraan antarkampung tarkam bikinan ...
# 4  montmelo pebalap tech ktm maverick vinales opt...

# %%
# !pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-24.3.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.9 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-24.3.1

# %%
# !pip install fcmeans
# Out:
# ERROR: Could not find a version that satisfies the requirement fcmeans (from versions: none)
# ERROR: No matching distribution found for fcmeans

# %%
# !pip install git+https://github.com/omadson/fuzzy-c-means.git
# Out:
# Collecting git+https://github.com/omadson/fuzzy-c-means.git
#   Cloning https://github.com/omadson/fuzzy-c-means.git to /tmp/pip-req-build-l5bzc9rs
#   Running command git clone --filter=blob:none --quiet https://github.com/omadson/fuzzy-c-means.git /tmp/pip-req-build-l5bzc9rs
#   Resolved https://github.com/omadson/fuzzy-c-means.git to commit c119596941d41d92dd2866ab3733af4d7b2d60c4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: joblib<2.0.0,>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from fuzzy-c-means==1.7.2) (1.4.2)
# Requirement already satisfied: numpy<2.0.0,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from fuzzy-c-means==1.7.2) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.4 in /usr/local/lib/python3.10/dist-packages (from fuzzy-c-means==1.7.2) (2.9.2)
# Collecting tabulate<0.9.0,>=0.8.9 (from fuzzy-c-means==1.7.2)
#   Downloading tabulate-0.8.10-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in /usr/local/lib/python3.10/dist-packages (from fuzzy-c-means==1.7.2) (4.66.6)
# Collecting typer<0.10.0,>=0.9.0 (from fuzzy-c-means==1.7.2)
#   Downloading typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means==1.7.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means==1.7.2) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means==1.7.2) (4.12.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.9.0->fuzzy-c-means==1.7.2) (8.1.7)
# Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Downloading typer-0.9.4-py3-none-any.whl (45 kB)
# Building wheels for collected packages: fuzzy-c-means
#   Building wheel for fuzzy-c-means (pyproject.toml) ... done
#   Created wheel for fuzzy-c-means: filename=fuzzy_c_means-1.7.2-py3-none-any.whl size=9135 sha256=7ec50eb413d2b12601d08eb49e60df97cfa828e802a5e661b1f784b6ae2c071a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cp59cg4o/wheels/60/c6/7e/4a7e67d476917eee0cbffb44f022ecc3ccd6e83d312b2dc329
# Successfully built fuzzy-c-means
# Installing collected packages: typer, tabulate, fuzzy-c-means
#   Attempting uninstall: typer
#     Found existing installation: typer 0.13.0
#     Uninstalling typer-0.13.0:
#       Successfully uninstalled typer-0.13.0
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.9.0
#     Uninstalling tabulate-0.9.0:
#       Successfully uninstalled tabulate-0.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.27.0 requires tabulate>=0.9, but you have tabulate 0.8.10 which is incompatible.
# Successfully installed fuzzy-c-means-1.7.2 tabulate-0.8.10 typer-0.9.4

# %%
# !pip install --upgrade tabulate
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.8.10)
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.8.10
#     Uninstalling tabulate-0.8.10:
#       Successfully uninstalled tabulate-0.8.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fuzzy-c-means 1.7.2 requires tabulate<0.9.0,>=0.8.9, but you have tabulate 0.9.0 which is incompatible.
# Successfully installed tabulate-0.9.0

# %%
# !pip install --force-reinstall bigframes
# Out:
# Collecting bigframes
#   Downloading bigframes-1.27.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting cloudpickle>=2.0.0 (from bigframes)
#   Downloading cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting fsspec>=2023.3.0 (from bigframes)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting gcsfs>=2023.3.0 (from bigframes)
#   Downloading gcsfs-2024.10.0-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting geopandas>=0.12.2 (from bigframes)
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3.0dev,>=2.15.0 (from bigframes)
#   Downloading google_auth-2.36.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-cloud-bigtable>=2.24.0 (from bigframes)
#   Downloading google_cloud_bigtable-2.27.0-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting google-cloud-pubsub>=2.21.4 (from bigframes)
#   Downloading google_cloud_pubsub-2.27.1-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting google-cloud-bigquery>=3.16.0 (from google-cloud-bigquery[bqstorage,pandas]>=3.16.0->bigframes)
#   Downloading google_cloud_bigquery-3.27.0-py2.py3-none-any.whl.metadata (8.6 kB)
# Collecting google-cloud-functions>=1.12.0 (from bigframes)
#   Downloading google_cloud_functions-1.18.1-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting google-cloud-bigquery-connection>=1.12.0 (from bigframes)
#   Downloading google_cloud_bigquery_connection-1.16.1-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting google-cloud-iam>=2.12.1 (from bigframes)
#   Downloading google_cloud_iam-2.16.1-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting google-cloud-resource-manager>=1.10.3 (from bigframes)
#   Downloading google_cloud_resource_manager-1.13.1-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting google-cloud-storage>=2.0.0 (from bigframes)
#   Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting ibis-framework<=9.2.0,>=9.0.0 (from ibis-framework[bigquery]<=9.2.0,>=9.0.0->bigframes)
#   Downloading ibis_framework-9.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting jellyfish>=0.8.9 (from bigframes)
#   Downloading jellyfish-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.6 kB)
# Collecting numpy>=1.24.0 (from bigframes)
#   Downloading numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting pandas>=1.5.3 (from bigframes)
#   Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting pyarrow>=10.0.1 (from bigframes)
#   Downloading pyarrow-18.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting pydata-google-auth>=1.8.2 (from bigframes)
#   Downloading pydata_google_auth-1.9.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting requests>=2.27.1 (from bigframes)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting scikit-learn>=1.2.2 (from bigframes)
#   Downloading scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting sqlalchemy<3.0dev,>=1.4 (from bigframes)
#   Downloading SQLAlchemy-2.0.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting sqlglot<25.2,>=23.6.3 (from bigframes)
#   Downloading sqlglot-25.1.0-py3-none-any.whl.metadata (19 kB)
# Collecting tabulate>=0.9 (from bigframes)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting ipywidgets>=7.7.1 (from bigframes)
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Collecting humanize>=4.6.0 (from bigframes)
#   Downloading humanize-4.11.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting matplotlib>=3.7.1 (from bigframes)
#   Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from gcsfs>=2023.3.0->bigframes)
#   Downloading aiohttp-3.11.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting decorator>4.1.2 (from gcsfs>=2023.3.0->bigframes)
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting google-auth-oauthlib (from gcsfs>=2023.3.0->bigframes)
#   Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting pyogrio>=0.7.2 (from geopandas>=0.12.2->bigframes)
#   Downloading pyogrio-0.10.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting packaging (from geopandas>=0.12.2->bigframes)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pyproj>=3.3.0 (from geopandas>=0.12.2->bigframes)
#   Downloading pyproj-3.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas>=0.12.2->bigframes)
#   Downloading shapely-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0dev,>=2.15.0->bigframes)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0dev,>=2.15.0->bigframes)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0dev,>=2.15.0->bigframes)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting google-api-core<3.0.0dev,>=2.11.1 (from google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=3.16.0->google-cloud-bigquery[bqstorage,pandas]>=3.16.0->bigframes)
#   Downloading google_api_core-2.23.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-cloud-core<3.0.0dev,>=2.4.1 (from google-cloud-bigquery>=3.16.0->google-cloud-bigquery[bqstorage,pandas]>=3.16.0->bigframes)
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media<3.0dev,>=2.0.0 (from google-cloud-bigquery>=3.16.0->google-cloud-bigquery[bqstorage,pandas]>=3.16.0->bigframes)
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting python-dateutil<3.0dev,>=2.7.3 (from google-cloud-bigquery>=3.16.0->google-cloud-bigquery[bqstorage,pandas]>=3.16.0->bigframes)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-cloud-bigquery-connection>=1.12.0->bigframes)
#   Downloading proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 (from google-cloud-bigquery-connection>=1.12.0->bigframes)
#   Downloading protobuf-5.29.0-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting grpc-google-iam-v1<1.0.0dev,>=0.12.4 (from google-cloud-bigquery-connection>=1.12.0->bigframes)
#   Downloading grpc_google_iam_v1-0.13.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting google-cloud-bigquery-storage<3.0.0dev,>=2.6.0 (from google-cloud-bigquery[bqstorage,pandas]>=3.16.0->bigframes)
#   Downloading google_cloud_bigquery_storage-2.27.0-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting grpcio<2.0dev,>=1.47.0 (from google-cloud-bigquery[bqstorage,pandas]>=3.16.0->bigframes)
#   Downloading grpcio-1.68.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting db-dtypes<2.0.0dev,>=0.3.0 (from google-cloud-bigquery[bqstorage,pandas]>=3.16.0->bigframes)
#   Downloading db_dtypes-1.3.1-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting grpcio-status>=1.33.2 (from google-cloud-pubsub>=2.21.4->bigframes)
#   Downloading grpcio_status-1.68.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting opentelemetry-api>=1.27.0 (from google-cloud-pubsub>=2.21.4->bigframes)
#   Downloading opentelemetry_api-1.28.2-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk>=1.27.0 (from google-cloud-pubsub>=2.21.4->bigframes)
#   Downloading opentelemetry_sdk-1.28.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage>=2.0.0->bigframes)
#   Downloading google_crc32c-1.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting atpublic<5,>=2.3 (from ibis-framework<=9.2.0,>=9.0.0->ibis-framework[bigquery]<=9.2.0,>=9.0.0->bigframes)
#   Downloading atpublic-4.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting parsy<3,>=2 (from ibis-framework<=9.2.0,>=9.0.0->ibis-framework[bigquery]<=9.2.0,>=9.0.0->bigframes)
#   Downloading parsy-2.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting pytz>=2022.7 (from ibis-framework<=9.2.0,>=9.0.0->ibis-framework[bigquery]<=9.2.0,>=9.0.0->bigframes)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting rich<14,>=12.4.4 (from ibis-framework<=9.2.0,>=9.0.0->ibis-framework[bigquery]<=9.2.0,>=9.0.0->bigframes)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting toolz<1,>=0.11 (from ibis-framework<=9.2.0,>=9.0.0->ibis-framework[bigquery]<=9.2.0,>=9.0.0->bigframes)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting typing-extensions<5,>=4.3.0 (from ibis-framework<=9.2.0,>=9.0.0->ibis-framework[bigquery]<=9.2.0,>=9.0.0->bigframes)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pyarrow>=10.0.1 (from bigframes)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting pyarrow-hotfix<1,>=0.4 (from ibis-framework[bigquery]<=9.2.0,>=9.0.0->bigframes)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting comm>=0.1.3 (from ipywidgets>=7.7.1->bigframes)
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting ipython>=6.1.0 (from ipywidgets>=7.7.1->bigframes)
#   Downloading ipython-8.29.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting traitlets>=4.3.1 (from ipywidgets>=7.7.1->bigframes)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets>=7.7.1->bigframes)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets>=7.7.1->bigframes)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.7.1->bigframes)
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.7.1->bigframes)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.7.1->bigframes)
#   Downloading fonttools-4.55.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (164 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.7.1->bigframes)
#   Downloading kiwisolver-1.4.7-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib>=3.7.1->bigframes)
#   Downloading pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=3.7.1->bigframes)
#   Downloading pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.5.3->bigframes)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting setuptools (from pydata-google-auth>=1.8.2->bigframes)
#   Downloading setuptools-75.6.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.27.1->bigframes)
#   Downloading charset_normalizer-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests>=2.27.1->bigframes)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.27.1->bigframes)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.27.1->bigframes)
#   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Collecting scipy>=1.6.0 (from scikit-learn>=1.2.2->bigframes)
#   Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=1.2.2->bigframes)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.2.2->bigframes)
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy<3.0dev,>=1.4->bigframes)
#   Downloading greenlet-3.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes)
#   Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes)
#   Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes)
#   Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes)
#   Downloading propcache-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.3.0->bigframes)
#   Downloading yarl-1.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (67 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0dev,>=2.11.1->google-api-core[grpc]<3.0.0dev,>=2.11.1->google-cloud-bigquery>=3.16.0->google-cloud-bigquery[bqstorage,pandas]>=3.16.0->bigframes)
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib->gcsfs>=2023.3.0->bigframes)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting prompt-toolkit<3.1.0,>=3.0.41 (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading prompt_toolkit-3.0.48-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack-data (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting exceptiongroup (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting pexpect>4.3 (from ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.27.0->google-cloud-pubsub>=2.21.4->bigframes)
#   Downloading Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting importlib-metadata<=8.5.0,>=6.0 (from opentelemetry-api>=1.27.0->google-cloud-pubsub>=2.21.4->bigframes)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-semantic-conventions==0.49b2 (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub>=2.21.4->bigframes)
#   Downloading opentelemetry_semantic_conventions-0.49b2-py3-none-any.whl.metadata (2.3 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.15.0->bigframes)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting six>=1.5 (from python-dateutil<3.0dev,>=2.7.3->google-cloud-bigquery>=3.16.0->google-cloud-bigquery[bqstorage,pandas]>=3.16.0->bigframes)
#   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=12.4.4->ibis-framework<=9.2.0,>=9.0.0->ibis-framework[bigquery]<=9.2.0,>=9.0.0->bigframes)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api>=1.27.0->google-cloud-pubsub>=2.21.4->bigframes)
#   Downloading wrapt-1.17.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting zipp>=3.20 (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub>=2.21.4->bigframes)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=12.4.4->ibis-framework<=9.2.0,>=9.0.0->ibis-framework[bigquery]<=9.2.0,>=9.0.0->bigframes)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting wcwidth (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2023.3.0->bigframes)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting executing>=1.2.0 (from stack-data->ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting pure-eval (from stack-data->ipython>=6.1.0->ipywidgets>=7.7.1->bigframes)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading bigframes-1.27.0-py2.py3-none-any.whl (755 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.1/755.1 kB 15.7 MB/s eta 0:00:00
# Downloading cloudpickle-3.1.0-py3-none-any.whl (22 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
# Downloading gcsfs-2024.10.0-py2.py3-none-any.whl (34 kB)
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading google_auth-2.36.0-py2.py3-none-any.whl (209 kB)
# Downloading google_cloud_bigquery-3.27.0-py2.py3-none-any.whl (240 kB)
# Downloading google_cloud_bigquery_connection-1.16.1-py2.py3-none-any.whl (61 kB)
# Downloading google_cloud_bigtable-2.27.0-py2.py3-none-any.whl (418 kB)
# Downloading google_cloud_functions-1.18.1-py2.py3-none-any.whl (141 kB)
# Downloading google_cloud_iam-2.16.1-py2.py3-none-any.whl (213 kB)
# Downloading google_cloud_pubsub-2.27.1-py2.py3-none-any.whl (289 kB)
# Downloading google_cloud_resource_manager-1.13.1-py2.py3-none-any.whl (358 kB)
# Downloading google_cloud_storage-2.18.2-py2.py3-none-any.whl (130 kB)
# Downloading humanize-4.11.0-py3-none-any.whl (128 kB)
# Downloading ibis_framework-9.2.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 45.8 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading jellyfish-1.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (335 kB)
# Downloading matplotlib-3.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 69.2 MB/s eta 0:00:00
# Downloading numpy-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 92.3 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 101.2 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 41.5 MB/s eta 0:00:00
# Downloading pydata_google_auth-1.9.0-py2.py3-none-any.whl (15 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 114.9 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 76.7 MB/s eta 0:00:00
# Downloading sqlglot-25.1.0-py3-none-any.whl (384 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading aiohttp-3.11.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 57.8 MB/s eta 0:00:00
# Downloading atpublic-4.1.0-py3-none-any.whl (5.0 kB)
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# Downloading charset_normalizer-3.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading db_dtypes-1.3.1-py2.py3-none-any.whl (18 kB)
# Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Downloading fonttools-4.55.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 96.0 MB/s eta 0:00:00
# Downloading google_api_core-2.23.0-py3-none-any.whl (156 kB)
# Downloading google_auth_oauthlib-1.2.1-py2.py3-none-any.whl (24 kB)
# Downloading google_cloud_bigquery_storage-2.27.0-py2.py3-none-any.whl (240 kB)
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Downloading greenlet-3.1.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (599 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.5/599.5 kB 21.3 MB/s eta 0:00:00
# Downloading grpc_google_iam_v1-0.13.1-py2.py3-none-any.whl (24 kB)
# Downloading grpcio-1.68.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 99.2 MB/s eta 0:00:00
# Downloading grpcio_status-1.68.0-py3-none-any.whl (14 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading ipython-8.29.0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.9/819.9 kB 33.7 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading kiwisolver-1.4.7-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 58.8 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.28.2-py3-none-any.whl (64 kB)
# Downloading opentelemetry_sdk-1.28.2-py3-none-any.whl (118 kB)
# Downloading opentelemetry_semantic_conventions-0.49b2-py3-none-any.whl (159 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading parsy-2.1-py3-none-any.whl (9.1 kB)
# Downloading pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 97.0 MB/s eta 0:00:00
# Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
# Downloading protobuf-5.29.0-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Downloading pyogrio-0.10.0-cp310-cp310-manylinux_2_28_x86_64.whl (23.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.9/23.9 MB 130.8 MB/s eta 0:00:00
# Downloading pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Downloading pyproj-3.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 116.0 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading scipy-1.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (41.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 43.0 MB/s eta 0:00:00
# Downloading shapely-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 75.7 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 68.8 MB/s eta 0:00:00
# Downloading setuptools-75.6.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.5 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
# Downloading Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Downloading frozenlist-1.5.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
# Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 54.6 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading multidict-6.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (124 kB)
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading prompt_toolkit-3.0.48-py3-none-any.whl (386 kB)
# Downloading propcache-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (208 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.3 MB/s eta 0:00:00
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Downloading yarl-1.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (319 kB)
# Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-2.4.1-py2.py3-none-any.whl (27 kB)
# Downloading executing-2.1.0-py2.py3-none-any.whl (25 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading wrapt-1.17.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (82 kB)
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Installing collected packages: wcwidth, pytz, pure-eval, ptyprocess, zipp, wrapt, widgetsnbextension, urllib3, tzdata, typing-extensions, traitlets, toolz, threadpoolctl, tabulate, sqlglot, six, setuptools, pyparsing, pygments, pyasn1, pyarrow-hotfix, protobuf, propcache, prompt-toolkit, pillow, pexpect, parsy, parso, packaging, oauthlib, numpy, mdurl, kiwisolver, jupyterlab-widgets, joblib, jellyfish, idna, humanize, grpcio, greenlet, google-crc32c, fsspec, frozenlist, fonttools, executing, exceptiongroup, decorator, cycler, cloudpickle, charset-normalizer, certifi, cachetools, attrs, atpublic, async-timeout, aiohappyeyeballs, sqlalchemy, shapely, scipy, rsa, requests, python-dateutil, pyproj, pyogrio, pyasn1-modules, pyarrow, proto-plus, multidict, matplotlib-inline, markdown-it-py, jedi, importlib-metadata, googleapis-common-protos, google-resumable-media, deprecated, contourpy, comm, asttokens, aiosignal, yarl, stack-data, scikit-learn, rich, requests-oauthlib, pandas, opentelemetry-api, matplotlib, grpcio-status, google-auth, opentelemetry-semantic-conventions, ipython, ibis-framework, grpc-google-iam-v1, google-auth-oauthlib, google-api-core, geopandas, db-dtypes, aiohttp, pydata-google-auth, opentelemetry-sdk, ipywidgets, google-cloud-core, google-cloud-storage, google-cloud-resource-manager, google-cloud-pubsub, google-cloud-iam, google-cloud-functions, google-cloud-bigtable, google-cloud-bigquery-storage, google-cloud-bigquery-connection, google-cloud-bigquery, gcsfs, bigframes
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.13
#     Uninstalling wcwidth-0.2.13:
#       Successfully uninstalled wcwidth-0.2.13
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.2
#     Uninstalling pytz-2024.2:
#       Successfully uninstalled pytz-2024.2
#   Attempting uninstall: ptyprocess
#     Found existing installation: ptyprocess 0.7.0
#     Uninstalling ptyprocess-0.7.0:
#       Successfully uninstalled ptyprocess-0.7.0
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.21.0
#     Uninstalling zipp-3.21.0:
#       Successfully uninstalled zipp-3.21.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.16.0
#     Uninstalling wrapt-1.16.0:
#       Successfully uninstalled wrapt-1.16.0
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2024.2
#     Uninstalling tzdata-2024.2:
#       Successfully uninstalled tzdata-2024.2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: toolz
#     Found existing installation: toolz 0.12.1
#     Uninstalling toolz-0.12.1:
#       Successfully uninstalled toolz-0.12.1
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.5.0
#     Uninstalling threadpoolctl-3.5.0:
#       Successfully uninstalled threadpoolctl-3.5.0
#   Attempting uninstall: tabulate
#     Found existing installation: tabulate 0.9.0
#     Uninstalling tabulate-0.9.0:
#       Successfully uninstalled tabulate-0.9.0
#   Attempting uninstall: sqlglot
#     Found existing installation: sqlglot 25.1.0
#     Uninstalling sqlglot-25.1.0:
#       Successfully uninstalled sqlglot-25.1.0
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.0
#     Uninstalling pyparsing-3.2.0:
#       Successfully uninstalled pyparsing-3.2.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.18.0
#     Uninstalling Pygments-2.18.0:
#       Successfully uninstalled Pygments-2.18.0
#   Attempting uninstall: pyasn1
#     Found existing installation: pyasn1 0.6.1
#     Uninstalling pyasn1-0.6.1:
#       Successfully uninstalled pyasn1-0.6.1
#   Attempting uninstall: pyarrow-hotfix
#     Found existing installation: pyarrow-hotfix 0.6
#     Uninstalling pyarrow-hotfix-0.6:
#       Successfully uninstalled pyarrow-hotfix-0.6
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.5
#     Uninstalling protobuf-4.25.5:
#       Successfully uninstalled protobuf-4.25.5
#   Attempting uninstall: propcache
#     Found existing installation: propcache 0.2.0
#     Uninstalling propcache-0.2.0:
#       Successfully uninstalled propcache-0.2.0
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt_toolkit 3.0.48
#     Uninstalling prompt_toolkit-3.0.48:
#       Successfully uninstalled prompt_toolkit-3.0.48
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.0.0
#     Uninstalling pillow-11.0.0:
#       Successfully uninstalled pillow-11.0.0
#   Attempting uninstall: pexpect
#     Found existing installation: pexpect 4.9.0
#     Uninstalling pexpect-4.9.0:
#       Successfully uninstalled pexpect-4.9.0
#   Attempting uninstall: parsy
#     Found existing installation: parsy 2.1
#     Uninstalling parsy-2.1:
#       Successfully uninstalled parsy-2.1
#   Attempting uninstall: parso
#     Found existing installation: parso 0.8.4
#     Uninstalling parso-0.8.4:
#       Successfully uninstalled parso-0.8.4
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: oauthlib
#     Found existing installation: oauthlib 3.2.2
#     Uninstalling oauthlib-3.2.2:
#       Successfully uninstalled oauthlib-3.2.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: mdurl
#     Found existing installation: mdurl 0.1.2
#     Uninstalling mdurl-0.1.2:
#       Successfully uninstalled mdurl-0.1.2
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.4.7
#     Uninstalling kiwisolver-1.4.7:
#       Successfully uninstalled kiwisolver-1.4.7
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab_widgets 3.0.13
#     Uninstalling jupyterlab_widgets-3.0.13:
#       Successfully uninstalled jupyterlab_widgets-3.0.13
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.4.2
#     Uninstalling joblib-1.4.2:
#       Successfully uninstalled joblib-1.4.2
#   Attempting uninstall: jellyfish
#     Found existing installation: jellyfish 1.1.0
#     Uninstalling jellyfish-1.1.0:
#       Successfully uninstalled jellyfish-1.1.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: humanize
#     Found existing installation: humanize 4.11.0
#     Uninstalling humanize-4.11.0:
#       Successfully uninstalled humanize-4.11.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.68.0
#     Uninstalling grpcio-1.68.0:
#       Successfully uninstalled grpcio-1.68.0
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.1.1
#     Uninstalling greenlet-3.1.1:
#       Successfully uninstalled greenlet-3.1.1
#   Attempting uninstall: google-crc32c
#     Found existing installation: google-crc32c 1.6.0
#     Uninstalling google-crc32c-1.6.0:
#       Successfully uninstalled google-crc32c-1.6.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: frozenlist
#     Found existing installation: frozenlist 1.5.0
#     Uninstalling frozenlist-1.5.0:
#       Successfully uninstalled frozenlist-1.5.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.55.0
#     Uninstalling fonttools-4.55.0:
#       Successfully uninstalled fonttools-4.55.0
#   Attempting uninstall: exceptiongroup
#     Found existing installation: exceptiongroup 1.2.2
#     Uninstalling exceptiongroup-1.2.2:
#       Successfully uninstalled exceptiongroup-1.2.2
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.0
#     Uninstalling cloudpickle-3.1.0:
#       Successfully uninstalled cloudpickle-3.1.0
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.4.0
#     Uninstalling charset-normalizer-3.4.0:
#       Successfully uninstalled charset-normalizer-3.4.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.8.30
#     Uninstalling certifi-2024.8.30:
#       Successfully uninstalled certifi-2024.8.30
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.5.0
#     Uninstalling cachetools-5.5.0:
#       Successfully uninstalled cachetools-5.5.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 24.2.0
#     Uninstalling attrs-24.2.0:
#       Successfully uninstalled attrs-24.2.0
#   Attempting uninstall: atpublic
#     Found existing installation: atpublic 4.1.0
#     Uninstalling atpublic-4.1.0:
#       Successfully uninstalled atpublic-4.1.0
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.3
#     Uninstalling async-timeout-4.0.3:
#       Successfully uninstalled async-timeout-4.0.3
#   Attempting uninstall: aiohappyeyeballs
#     Found existing installation: aiohappyeyeballs 2.4.3
#     Uninstalling aiohappyeyeballs-2.4.3:
#       Successfully uninstalled aiohappyeyeballs-2.4.3
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.36
#     Uninstalling SQLAlchemy-2.0.36:
#       Successfully uninstalled SQLAlchemy-2.0.36
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.0.6
#     Uninstalling shapely-2.0.6:
#       Successfully uninstalled shapely-2.0.6
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: pyproj
#     Found existing installation: pyproj 3.7.0
#     Uninstalling pyproj-3.7.0:
#       Successfully uninstalled pyproj-3.7.0
#   Attempting uninstall: pyogrio
#     Found existing installation: pyogrio 0.10.0
#     Uninstalling pyogrio-0.10.0:
#       Successfully uninstalled pyogrio-0.10.0
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1_modules 0.4.1
#     Uninstalling pyasn1_modules-0.4.1:
#       Successfully uninstalled pyasn1_modules-0.4.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
#   Attempting uninstall: proto-plus
#     Found existing installation: proto-plus 1.25.0
#     Uninstalling proto-plus-1.25.0:
#       Successfully uninstalled proto-plus-1.25.0
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.1.0
#     Uninstalling multidict-6.1.0:
#       Successfully uninstalled multidict-6.1.0
#   Attempting uninstall: matplotlib-inline
#     Found existing installation: matplotlib-inline 0.1.7
#     Uninstalling matplotlib-inline-0.1.7:
#       Successfully uninstalled matplotlib-inline-0.1.7
#   Attempting uninstall: markdown-it-py
#     Found existing installation: markdown-it-py 3.0.0
#     Uninstalling markdown-it-py-3.0.0:
#       Successfully uninstalled markdown-it-py-3.0.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
#   Attempting uninstall: googleapis-common-protos
#     Found existing installation: googleapis-common-protos 1.66.0
#     Uninstalling googleapis-common-protos-1.66.0:
#       Successfully uninstalled googleapis-common-protos-1.66.0
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 2.7.2
#     Uninstalling google-resumable-media-2.7.2:
#       Successfully uninstalled google-resumable-media-2.7.2
#   Attempting uninstall: deprecated
#     Found existing installation: Deprecated 1.2.15
#     Uninstalling Deprecated-1.2.15:
#       Successfully uninstalled Deprecated-1.2.15
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.1
#     Uninstalling contourpy-1.3.1:
#       Successfully uninstalled contourpy-1.3.1
#   Attempting uninstall: aiosignal
#     Found existing installation: aiosignal 1.3.1
#     Uninstalling aiosignal-1.3.1:
#       Successfully uninstalled aiosignal-1.3.1
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.17.2
#     Uninstalling yarl-1.17.2:
#       Successfully uninstalled yarl-1.17.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.5.2
#     Uninstalling scikit-learn-1.5.2:
#       Successfully uninstalled scikit-learn-1.5.2
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: requests-oauthlib
#     Found existing installation: requests-oauthlib 1.3.1
#     Uninstalling requests-oauthlib-1.3.1:
#       Successfully uninstalled requests-oauthlib-1.3.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.28.2
#     Uninstalling opentelemetry-api-1.28.2:
#       Successfully uninstalled opentelemetry-api-1.28.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.0
#     Uninstalling matplotlib-3.8.0:
#       Successfully uninstalled matplotlib-3.8.0
#   Attempting uninstall: grpcio-status
#     Found existing installation: grpcio-status 1.62.3
#     Uninstalling grpcio-status-1.62.3:
#       Successfully uninstalled grpcio-status-1.62.3
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.27.0
#     Uninstalling google-auth-2.27.0:
#       Successfully uninstalled google-auth-2.27.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.49b2
#     Uninstalling opentelemetry-semantic-conventions-0.49b2:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.49b2
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: ibis-framework
#     Found existing installation: ibis-framework 9.2.0
#     Uninstalling ibis-framework-9.2.0:
#       Successfully uninstalled ibis-framework-9.2.0
#   Attempting uninstall: grpc-google-iam-v1
#     Found existing installation: grpc-google-iam-v1 0.13.1
#     Uninstalling grpc-google-iam-v1-0.13.1:
#       Successfully uninstalled grpc-google-iam-v1-0.13.1
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.1
#     Uninstalling google-auth-oauthlib-1.2.1:
#       Successfully uninstalled google-auth-oauthlib-1.2.1
#   Attempting uninstall: google-api-core
#     Found existing installation: google-api-core 2.19.2
#     Uninstalling google-api-core-2.19.2:
#       Successfully uninstalled google-api-core-2.19.2
#   Attempting uninstall: geopandas
#     Found existing installation: geopandas 1.0.1
#     Uninstalling geopandas-1.0.1:
#       Successfully uninstalled geopandas-1.0.1
#   Attempting uninstall: db-dtypes
#     Found existing installation: db-dtypes 1.3.1
#     Uninstalling db-dtypes-1.3.1:
#       Successfully uninstalled db-dtypes-1.3.1
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.2
#     Uninstalling aiohttp-3.11.2:
#       Successfully uninstalled aiohttp-3.11.2
#   Attempting uninstall: pydata-google-auth
#     Found existing installation: pydata-google-auth 1.8.2
#     Uninstalling pydata-google-auth-1.8.2:
#       Successfully uninstalled pydata-google-auth-1.8.2
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.28.2
#     Uninstalling opentelemetry-sdk-1.28.2:
#       Successfully uninstalled opentelemetry-sdk-1.28.2
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 2.4.1
#     Uninstalling google-cloud-core-2.4.1:
#       Successfully uninstalled google-cloud-core-2.4.1
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 2.8.0
#     Uninstalling google-cloud-storage-2.8.0:
#       Successfully uninstalled google-cloud-storage-2.8.0
#   Attempting uninstall: google-cloud-resource-manager
#     Found existing installation: google-cloud-resource-manager 1.13.1
#     Uninstalling google-cloud-resource-manager-1.13.1:
#       Successfully uninstalled google-cloud-resource-manager-1.13.1
#   Attempting uninstall: google-cloud-pubsub
#     Found existing installation: google-cloud-pubsub 2.27.1
#     Uninstalling google-cloud-pubsub-2.27.1:
#       Successfully uninstalled google-cloud-pubsub-2.27.1
#   Attempting uninstall: google-cloud-iam
#     Found existing installation: google-cloud-iam 2.16.1
#     Uninstalling google-cloud-iam-2.16.1:
#       Successfully uninstalled google-cloud-iam-2.16.1
#   Attempting uninstall: google-cloud-functions
#     Found existing installation: google-cloud-functions 1.18.1
#     Uninstalling google-cloud-functions-1.18.1:
#       Successfully uninstalled google-cloud-functions-1.18.1
#   Attempting uninstall: google-cloud-bigtable
#     Found existing installation: google-cloud-bigtable 2.27.0
#     Uninstalling google-cloud-bigtable-2.27.0:
#       Successfully uninstalled google-cloud-bigtable-2.27.0
#   Attempting uninstall: google-cloud-bigquery-storage
#     Found existing installation: google-cloud-bigquery-storage 2.27.0
#     Uninstalling google-cloud-bigquery-storage-2.27.0:
#       Successfully uninstalled google-cloud-bigquery-storage-2.27.0
#   Attempting uninstall: google-cloud-bigquery-connection
#     Found existing installation: google-cloud-bigquery-connection 1.16.1
#     Uninstalling google-cloud-bigquery-connection-1.16.1:
#       Successfully uninstalled google-cloud-bigquery-connection-1.16.1
#   Attempting uninstall: google-cloud-bigquery
#     Found existing installation: google-cloud-bigquery 3.25.0
#     Uninstalling google-cloud-bigquery-3.25.0:
#       Successfully uninstalled google-cloud-bigquery-3.25.0
#   Attempting uninstall: gcsfs
#     Found existing installation: gcsfs 2024.10.0
#     Uninstalling gcsfs-2024.10.0:
#       Successfully uninstalled gcsfs-2024.10.0
#   Attempting uninstall: bigframes
#     Found existing installation: bigframes 1.27.0
#     Uninstalling bigframes-1.27.0:
#       Successfully uninstalled bigframes-1.27.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 2.2.3 which is incompatible.
# cupy-cuda12x 12.2.0 requires numpy<1.27,>=1.20, but you have numpy 2.1.3 which is incompatible.
# fuzzy-c-means 1.7.2 requires numpy<2.0.0,>=1.21.1, but you have numpy 2.1.3 which is incompatible.
# fuzzy-c-means 1.7.2 requires tabulate<0.9.0,>=0.8.9, but you have tabulate 0.9.0 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.1.3 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.14.1 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.27.0, but you have google-auth 2.36.0 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.29.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# langchain 0.3.7 requires async-timeout<5.0.0,>=4.0.0; python_version < "3.11", but you have async-timeout 5.0.1 which is incompatible.
# langchain 0.3.7 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.1.3 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.1.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.1.3 which is incompatible.
# pytensor 2.26.3 requires numpy<2,>=1.17.0, but you have numpy 2.1.3 which is incompatible.
# tensorflow 2.17.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.1.3 which is incompatible.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.0 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.0 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.1.3 which is incompatible.
# tweepy 4.14.0 requires requests-oauthlib<2,>=1.2.0, but you have requests-oauthlib 2.0.0 which is incompatible.
# Successfully installed aiohappyeyeballs-2.4.3 aiohttp-3.11.8 aiosignal-1.3.1 asttokens-2.4.1 async-timeout-5.0.1 atpublic-4.1.0 attrs-24.2.0 bigframes-1.27.0 cachetools-5.5.0 certifi-2024.8.30 charset-normalizer-3.4.0 cloudpickle-3.1.0 comm-0.2.2 contourpy-1.3.1 cycler-0.12.1 db-dtypes-1.3.1 decorator-5.1.1 deprecated-1.2.15 exceptiongroup-1.2.2 executing-2.1.0 fonttools-4.55.0 frozenlist-1.5.0 fsspec-2024.10.0 gcsfs-2024.10.0 geopandas-1.0.1 google-api-core-2.23.0 google-auth-2.36.0 google-auth-oauthlib-1.2.1 google-cloud-bigquery-3.27.0 google-cloud-bigquery-connection-1.16.1 google-cloud-bigquery-storage-2.27.0 google-cloud-bigtable-2.27.0 google-cloud-core-2.4.1 google-cloud-functions-1.18.1 google-cloud-iam-2.16.1 google-cloud-pubsub-2.27.1 google-cloud-resource-manager-1.13.1 google-cloud-storage-2.18.2 google-crc32c-1.6.0 google-resumable-media-2.7.2 googleapis-common-protos-1.66.0 greenlet-3.1.1 grpc-google-iam-v1-0.13.1 grpcio-1.68.0 grpcio-status-1.68.0 humanize-4.11.0 ibis-framework-9.2.0 idna-3.10 importlib-metadata-8.5.0 ipython-8.29.0 ipywidgets-8.1.5 jedi-0.19.2 jellyfish-1.1.0 joblib-1.4.2 jupyterlab-widgets-3.0.13 kiwisolver-1.4.7 markdown-it-py-3.0.0 matplotlib-3.9.2 matplotlib-inline-0.1.7 mdurl-0.1.2 multidict-6.1.0 numpy-2.1.3 oauthlib-3.2.2 opentelemetry-api-1.28.2 opentelemetry-sdk-1.28.2 opentelemetry-semantic-conventions-0.49b2 packaging-24.2 pandas-2.2.3 parso-0.8.4 parsy-2.1 pexpect-4.9.0 pillow-11.0.0 prompt-toolkit-3.0.48 propcache-0.2.0 proto-plus-1.25.0 protobuf-5.29.0 ptyprocess-0.7.0 pure-eval-0.2.3 pyarrow-17.0.0 pyarrow-hotfix-0.6 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydata-google-auth-1.9.0 pygments-2.18.0 pyogrio-0.10.0 pyparsing-3.2.0 pyproj-3.7.0 python-dateutil-2.9.0.post0 pytz-2024.2 requests-2.32.3 requests-oauthlib-2.0.0 rich-13.9.4 rsa-4.9 scikit-learn-1.5.2 scipy-1.14.1 setuptools-75.6.0 shapely-2.0.6 six-1.16.0 sqlalchemy-2.0.36 sqlglot-25.1.0 stack-data-0.6.3 tabulate-0.9.0 threadpoolctl-3.5.0 toolz-0.12.1 traitlets-5.14.3 typing-extensions-4.12.2 tzdata-2024.2 urllib3-2.2.3 wcwidth-0.2.13 widgetsnbextension-4.0.13 wrapt-1.17.0 yarl-1.18.0 zipp-3.21.0

# %%
import pandas as pd
import numpy as np
import re
import string
import pickle
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import TruncatedSVD
from fcmeans import FCM
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import nltk
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-33c906567edb> in <cell line: 12>()
#      10 from sklearn.metrics.pairwise import cosine_similarity
#      11 from sklearn.decomposition import TruncatedSVD
# ---> 12 from fcmeans import FCM
#      13 from sklearn.preprocessing import LabelEncoder
#      14 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'fcmeans'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
